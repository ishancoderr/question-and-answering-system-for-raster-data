# %%
from langchain.graphs import Neo4jGraph

# Define Neo4j credentials
NEO4J_URI = "neo4j+s://bb36aed3.databases.neo4j.io"
NEO4J_USERNAME = "neo4j"
NEO4J_PASSWORD = "iOwGDhlGib_lRZkmrynDcb9GUABvvZ_GLEG4jnoRtJE"

# Initialize Neo4jGraph
graph = Neo4jGraph(
    url=NEO4J_URI,
    username=NEO4J_USERNAME,
    password=NEO4J_PASSWORD
)

# %% [markdown]
# **What is LangSmith?**
#
# LangSmith is a platform and toolkit developed by LangChain (the creators of the popular LangChain framework) for debugging, testing, evaluating, and monitoring applications built with language models (LLMs). It is particularly useful for developers working with LLMs like OpenAI's GPT, Anthropic's Claude, or other models integrated into LangChain.
#
# **Why Use LangSmith?**
#
# If you're building applications with LLMs, debugging and evaluating them can be challenging due to their non-deterministic nature. LangSmith provides a structured way to:
#
# Understand how your LLM is behaving.
#
# Identify and fix issues in your prompts or workflows.
#
# Ensure your application is reliable and performs well in production.

# %%
import getpass
import os

# %%
# Delete the existing key if set
os.environ.pop("OPENAI_API_KEY", None)

# %%
# Ask for a new API key
os.environ["OPENAI_API_KEY"] = getpass.getpass("Enter your OpenAI API key: ")


os.environ["LANGCHAIN_TRACING_V2"] = "true"
os.environ["LANGCHAIN_ENDPOINT"] = "https://api.smith.langchain.com"
os.environ["LANGCHAIN_API_KEY"] = "llsv2_pt_9677d509faea45e6a85e758257bb8d24_86a6d412aa"

# %%
from langchain.chains import GraphCypherQAChain
from langchain_community.graphs import Neo4jGraph
from langchain_openai import ChatOpenAI
import os

chain = GraphCypherQAChain.from_llm(
    graph=graph,
    cypher_llm=ChatOpenAI(temperature=0, model="gpt-4o-mini"), # gpt-4o-mini	gpt-3.5-turbo
    qa_llm=ChatOpenAI(temperature=0, model="gpt-3.5-turbo-16k"),
    verbose=True,
    allow_dangerous_requests=True
)

# %%
metadata_text = """

entities: products 
product (name="Sentinel-2 L2A Maja"
Organization: name="German Aerospace Center (DLR)"
Person: name="Pablo Angelo"
ReferenceSystem: name="EPSG:4326 (WGS 84)"
Keyword: text="Satellite"
Keyword: text="Earth Observation"
Keyword: text="Multispectral"
Keyword: text="Sentinel-2"
Keyword: text="MSI"
Keyword: text="Level 2A"
Keyword: text="MAJA"
Keyword: text="Atmospheric Correction"
Keyword: text="Cloud Detection"
DownloadLink: url="https://tinyurl.com/mr2x5hm5", 
SensorType: name="Optical"
Date: "2024-07-12T09:25:33"
ISOStandard: name="ISO 19115 : 2003/Cor.1:2006"
OrbitType: name="LEO"
DOI: "10.15489/ifczsszkcp63"
GeoJSON: url="https://tinyurl.com/yz9rn2xs"

Visualization: url="https://tinyurl.com/2m44wna5"
Tile: name="SENTINEL2A_20191116-103650-357_L2A_T32UMB_C_V1-2"
Tile: name="SENTINEL2A_20191116-103708-854_L2A_T32ULA_C_V1-2"
Tile: name="SENTINEL2A_20191116-103704-633_L2A_T32UMA_C_V1-2"
Tile: name="SENTINEL2A_20191116-103737-445_L2A_T32ULU_C_V1-2"
Tile: name="SENTINEL2A_20191116-103751-825_L2A_T32TLT_C_V1-2"
Tile: name="SENTINEL2A_20191116-103742-760_L2A_T32TNT_C_V1-2"
Tile: name="SENTINEL2A_20191116-103733-256_L2A_T32UMU_C_V1-2"
Spatial EXtent: name='5.7635, 46.7937, 15.1528, 55.9456'

Relationships:
Sentinel-2 L2A Maja:
(Product)-[:CONTACT_INFORMATION]->(Organization)
(Product)-[:POINT_OF_CONTACT]->(Person)
(Product)-[:REFERENCE_SYSTEM]->(ReferenceSystem)
(Product)-[:DESCRIBED_BY]->(Keyword)
(Product)-[:HAS_DOWNLOAD_LINK]->(DownloadLink)
(Product)-[:TEMPORAL_EXTENT]->(Date)
(Product)-[:SPATIAL_EXTENT]->(SpatialExtent) 
(Product)-[:HAS_SENSOR_TYPE]->(SensorType)
(Product)-[:HAS_ISO_STANDARD]->(ISOStandard)
(Product)-[:HAS_ORBIT_TYPE]->(OrbitType)
(Product)-[:HAS_DOI]->(DOI))
(Product)-[:HAS_GEOJSON]->(GeoJSON)
(Product)-[:HAS_VISUALIZATION]->(Visualization)
(Product)-[:HAS_TILES]->(Tile)

entities: products 
product (name="S5P Tropomi L4 P1D NO2surf"
Organization: name="DLR - German Remote Sensing Data Center (DFD))"
ReferenceSystem: name="EPSG:4326 (WGS 84)"
visualisation: url=https://tinyurl.com/2k9uhbc8
SensorType: name="Atmospheric"
Date: "2023-01-25T00:00:00Z"
ISOStandard: name="ISO 19115 : 2003/Cor.1:2006"
OrbitType: name="LEO"
Platform: name="Sentinel-5P"
Instrument: name="TROPOMI"
geojson:url= 'https://tinyurl.com/4futv537'
CompositeType: name="P1D"
SpatialExtent: name="3.755, 46.79, 15.275, 54.47"

relationships:
S5P Tropomi L4 P1D NO2surf:
(Product)-[:CONTACT_INFORMATION]->(Organization)
(Product)-[:REFERENCE_SYSTEM]->(ReferenceSystem)
(Product)-[:HAS_DOWNLOAD_LINK]->(DownloadLink)
(Product)-[:TEMPORAL_EXTENT]->(Date)
(Product)-[:SPATIAL_EXTENT]->(SpatialExtent)
(Product)-[:HAS_SENSOR_TYPE]->(SensorType)
(Product)-[:HAS_ISO_STANDARD]->(ISOStandard)
(Product)-[:HAS_ORBIT_TYPE]->(OrbitType)
(Product)-[:HAS_PLATFORM]->(Platform)
(Product)-[:HAS_INSTRUMENT]->(Instrument)
(Product)-[:HAS_COMPOSITE_TYPE]->(CompositeType)


entities: products 
product (name="EnMAP L0 HSI Quicklook Products"
Organization: name="DLR/EOC Photogrammetry and Image Analysis"
ReferenceSystem: name="EPSG:4326 (WGS 84)"
Visualization: url="https://tinyurl.com/46ne586m"
SensorType: name="Optical"
Date: "2022-04-27T00:00:00Z"
ISOStandard: name="ISO 19115 : 2003/Cor.1:2006"
OrbitType: name="LEO"
Platform: name="EnMAP"
Instrument: name="HSI"
CompositeType: name="P1D"
SpatialExtent: name="-180, -90, 180, 90"
 
relationships:
EnMAP L0 HSI Quicklook Products:

(Product)-[:CONTACT_INFORMATION]->(Organization)
(Product)-[:REFERENCE_SYSTEM]->(ReferenceSystem)
(Product)-[:HAS_VISUALIZATION]->(Visualization)
(Product)-[:TEMPORAL_EXTENT]->(Date)
(Product)-[:SPATIAL_EXTENT]->(SpatialExtent)
(Product)-[:HAS_SENSOR_TYPE]->(SensorType)
(Product)-[:HAS_ISO_STANDARD]->(ISOStandard)
(Product)-[:HAS_ORBIT_TYPE]->(OrbitType)
(Product)-[:HAS_PLATFORM]->(Platform)
(Product)-[:HAS_INSTRUMENT]->(Instrument)
(Product)-[:HAS_COMPOSITE_TYPE]->(CompositeType)

entities: products 
product (name="EnMAP L2A HSI Products"
Organization: name="DLR/EOC Photogrammetry and Image Analysis"
ReferenceSystem: name="EPSG:4326 (WGS 84)"
Visualization: url="https://tinyurl.com/mr44wven"
SensorType: name="Optical"
Date: "2022-04-27T00:00:00Z"
ISOStandard: name="ISO 19115 : 2003/Cor.1:2006"
OrbitType: name="LEO"
Platform: name="EnMAP"
Instrument: name="HSI"
CompositeType: name="P1D"
SpatialExtent: name="-180, -90, 180, 90"

relationship:
EnMAP L2A HSI Products

(Product)-[:CONTACT_INFORMATION]->(Organization)
(Product)-[:REFERENCE_SYSTEM]->(ReferenceSystem)
(Product)-[:HAS_VISUALIZATION]->(Visualization)
(Product)-[:TEMPORAL_EXTENT]->(Date)
(Product)-[:SPATIAL_EXTENT]->(SpatialExtent)
(Product)-[:HAS_SENSOR_TYPE]->(SensorType)
(Product)-[:HAS_ISO_STANDARD]->(ISOStandard)
(Product)-[:HAS_ORBIT_TYPE]->(OrbitType)
(Product)-[:HAS_PLATFORM]->(Platform)
(Product)-[:HAS_INSTRUMENT]->(Instrument)
(Product)-[:HAS_COMPOSITE_TYPE]->(CompositeType)

entities: products 
product (name="Sentinel-1 Floodmasks (Data4Human)"
Organization: name="DLR/EOC Geo-Risks and Civil Security"
ReferenceSystem: name="EPSG:4326 (WGS 84)"
Visualization: url="https://tinyurl.com/2z5jrw6u"
SensorType: name="RADAR"
Date: "2020-01-08T16:22:00Z /""
SpatialExtent: name="-33.0826, -13.3956, -24.9789, 40.9334"

relationship:
Sentinel-1 Floodmasks (Data4Human) 

(Product)-[:CONTACT_INFORMATION]->(Organization)
(Product)-[:REFERENCE_SYSTEM]->(ReferenceSystem)
(Product)-[:HAS_VISUALIZATION]->(Visualization)
(Product)-[:TEMPORAL_EXTENT]->(Date)
(Product)-[:SPATIAL_EXTENT]->(SpatialExtent)
(Product)-[:HAS_SENSOR_TYPE]->(SensorType)

entities: products 
product (
name="Sentinel-2 L3A Monthly WASP Products"
Organization: name="DLR/EOC Remote Sensing Technology Institute, Photogrammetry and Image Analysis"
ReferenceSystem: name="EPSG:4326 (WGS 84)"
Visualization: url="https://tinyurl.com/2f69jbbb"
SensorType: name="Optical"
Date: "2020-01-08T16:22:00Z"
ISOStandard: name="ISO 19115 : 2003/Cor.1:2006"
OrbitType: name="LEO"
Platform: name="Sentinel-2"
Instrument: name="MSI"
CompositeType: name=" P1M"
SpatialExtent: name=" 5.7635, 46.7937, 15.1528, 55.9456"

relatuionship:

Sentinel-2 L3A Monthly WASP Products 

(Product)-[:CONTACT_INFORMATION]->(Organization)
(Product)-[:REFERENCE_SYSTEM]->(ReferenceSystem)
(Product)-[:HAS_VISUALIZATION]->(Visualization)
(Product)-[:TEMPORAL_EXTENT]->(Date)
(Product)-[:SPATIAL_EXTENT]->(SpatialExtent)
(Product)-[:HAS_SENSOR_TYPE]->(SensorType)
(Product)-[:HAS_ISO_STANDARD]->(ISOStandard)
(Product)-[:HAS_ORBIT_TYPE]->(OrbitType)
(Product)-[:HAS_PLATFORM]->(Platform)
(Product)-[:HAS_INSTRUMENT]->(Instrument)
(Product)-[:HAS_COMPOSITE_TYPE]->(CompositeType)


entities: products 
product (name="S5P Tropomi L3 P1D CF"
Organization: name="DLR - German Remote Sensing Data Center (DFD)"
ReferenceSystem: name="EPSG:4326 (WGS 84)"
Visualization: url="https://tinyurl.com/372mvy6y"
SensorType: name="ATMOSPHERIC"
Date: "2017-11-08T00:00:00Z /"
ISOStandard: name="Metadata (ISO19139)"
OrbitType: name="LEO"
Platform: name="Sentinel-5P"
Instrument: name="TROPOMI"
CompositeType: name=" P1D"
SpatialExtent: name=" -180, -90, 180, 90"

relationship:

S5P Tropomi L3 P1D CF 

(Product)-[:CONTACT_INFORMATION]->(Organization)
(Product)-[:REFERENCE_SYSTEM]->(ReferenceSystem)
(Product)-[:HAS_VISUALIZATION]->(Visualization)
(Product)-[:TEMPORAL_EXTENT]->(Date)
(Product)-[:SPATIAL_EXTENT]->(SpatialExtent)
(Product)-[:HAS_SENSOR_TYPE]->(SensorType)
(Product)-[:HAS_ISO_STANDARD]->(ISOStandard)
(Product)-[:HAS_ORBIT_TYPE]->(OrbitType)
(Product)-[:HAS_PLATFORM]->(Platform)
(Product)-[:HAS_INSTRUMENT]->(Instrument)
(Product)-[:HAS_COMPOSITE_TYPE]->(CompositeType)

entities: products 
product (properties:
name="S5P Tropomi L3 P1D COT"
Organization: name="DLR - German Remote Sensing Data Center (DFD)"
ReferenceSystem: name="EPSG:4326 (WGS 84)"
Visualization: url="https://tinyurl.com/yu6e8d74"
SensorType: name="ATMOSPHERIC"
Date: "2017-11-08T00:00:00Z /"
ISOStandard: name="Metadata (ISO19139)"
OrbitType: name="LEO"
Platform: name="Sentinel-5P"
Instrument: name="TROPOMI"
CompositeType: name=" P1D"
SpatialExtent: name=" -180, -90, 180, 90"

relationship:

S5P Tropomi L3 P1D COT 

(Product)-[:CONTACT_INFORMATION]->(Organization)
(Product)-[:REFERENCE_SYSTEM]->(ReferenceSystem)
(Product)-[:HAS_VISUALIZATION]->(Visualization)
(Product)-[:TEMPORAL_EXTENT]->(Date)
(Product)-[:SPATIAL_EXTENT]->(SpatialExtent)
(Product)-[:HAS_SENSOR_TYPE]->(SensorType)
(Product)-[:HAS_ISO_STANDARD]->(ISOStandard)
(Product)-[:HAS_ORBIT_TYPE]->(OrbitType)
(Product)-[:HAS_PLATFORM]->(Platform)
(Product)-[:HAS_INSTRUMENT]->(Instrument)
(Product)-[:HAS_COMPOSITE_TYPE]->(CompositeType)

entities: products 
product (name="S5P Tropomi L3 P1D CTH"
Organization: name="DLR - German Remote Sensing Data Center (DFD)"
ReferenceSystem: name="EPSG:4326 (WGS 84)"
Visualization: url="https://tinyurl.com/3nrcetpz"
SensorType: name="ATMOSPHERIC"
Date: "2017-11-08T00:00:00Z /"
ISOStandard: name="Metadata (ISO19139)"
OrbitType: name="LEO"
Platform: name="Sentinel-5P"
Instrument: name="TROPOMI"
CompositeType: name=" P1D"
SpatialExtent: name=" -180, -90, 180, 90"

relationship:
S5P Tropomi L3 P1D CTH

(Product)-[:CONTACT_INFORMATION]->(Organization)
(Product)-[:REFERENCE_SYSTEM]->(ReferenceSystem)
(Product)-[:HAS_VISUALIZATION]->(Visualization)
(Product)-[:TEMPORAL_EXTENT]->(Date)
(Product)-[:SPATIAL_EXTENT]->(SpatialExtent)
(Product)-[:HAS_SENSOR_TYPE]->(SensorType)
(Product)-[:HAS_ISO_STANDARD]->(ISOStandard)
(Product)-[:HAS_ORBIT_TYPE]->(OrbitType)
(Product)-[:HAS_PLATFORM]->(Platform)
(Product)-[:HAS_INSTRUMENT]->(Instrument)
(Product)-[:HAS_COMPOSITE_TYPE]->(CompositeType)

entities: products 
product (name="S5P Tropomi L3 P1D HCHO"
Organization: name="DLR - German Remote Sensing Data Center (DFD)"
ReferenceSystem: name="EPSG:4326 (WGS 84)"
Visualization: url="https://tinyurl.com/47wjh48c"
SensorType: name="ATMOSPHERIC"
Date: "2017-11-08T00:00:00Z /"
ISOStandard: name="Metadata (ISO19139)"
OrbitType: name="LEO"
Platform: name="Sentinel-5P"
Instrument: name="TROPOMI"
CompositeType: name=" P1D"
SpatialExtent: name=" -180, -90, 180, 90"

relationship:
S5P Tropomi L3 P1D HCHO

(Product)-[:CONTACT_INFORMATION]->(Organization)
(Product)-[:REFERENCE_SYSTEM]->(ReferenceSystem)
(Product)-[:HAS_VISUALIZATION]->(Visualization)
(Product)-[:TEMPORAL_EXTENT]->(Date)
(Product)-[:SPATIAL_EXTENT]->(SpatialExtent)
(Product)-[:HAS_SENSOR_TYPE]->(SensorType)
(Product)-[:HAS_ISO_STANDARD]->(ISOStandard)
(Product)-[:HAS_ORBIT_TYPE]->(OrbitType)
(Product)-[:HAS_PLATFORM]->(Platform)
(Product)-[:HAS_INSTRUMENT]->(Instrument)
(Product)-[:HAS_COMPOSITE_TYPE]->(CompositeType)


entities: products 
product (name="S5P Tropomi L3 P1D O3"
Organization: name="DLR - German Remote Sensing Data Center (DFD)"
ReferenceSystem: name="EPSG:4326 (WGS 84)"
Visualization: url="https://tinyurl.com/ytuwvfc9"
SensorType: name="ATMOSPHERIC"
Date: "2017-11-08T00:00:00Z /"
ISOStandard: name="Metadata (ISO19139)"
OrbitType: name="LEO"
Platform: name="Sentinel-5P"
Instrument: name="TROPOMI"
CompositeType: name=" P1D"
SpatialExtent: name=" -180, -90, 180, 90"

relationship:

S5P Tropomi L3 P1D O3

(Product)-[:CONTACT_INFORMATION]->(Organization)
(Product)-[:REFERENCE_SYSTEM]->(ReferenceSystem)
(Product)-[:HAS_VISUALIZATION]->(Visualization)
(Product)-[:TEMPORAL_EXTENT]->(Date)
(Product)-[:SPATIAL_EXTENT]->(SpatialExtent)
(Product)-[:HAS_SENSOR_TYPE]->(SensorType)
(Product)-[:HAS_ISO_STANDARD]->(ISOStandard)
(Product)-[:HAS_ORBIT_TYPE]->(OrbitType)
(Product)-[:HAS_PLATFORM]->(Platform)
(Product)-[:HAS_INSTRUMENT]->(Instrument)
(Product)-[:HAS_COMPOSITE_TYPE]->(CompositeType)

entities: products 
product (name="S5P Tropomi L3 P1D SO2"
Organization: name="DLR - German Remote Sensing Data Center (DFD)"
ReferenceSystem: name="EPSG:4326 (WGS 84)"
Visualization: url="https://tinyurl.com/8xp7wze7"
SensorType: name="ATMOSPHERIC"
Date: "2017-11-08T00:00:00Z /"
ISOStandard: name="Metadata (ISO19139)"
OrbitType: name="LEO"
Platform: name="Sentinel-5P"
Instrument: name="TROPOMI"
CompositeType: name=" P1D"
SpatialExtent: name=" -180, -90, 180, 90"

relationship:

S5P Tropomi L3 P1D SO2

(Product)-[:CONTACT_INFORMATION]->(Organization)
(Product)-[:REFERENCE_SYSTEM]->(ReferenceSystem)
(Product)-[:HAS_VISUALIZATION]->(Visualization)
(Product)-[:TEMPORAL_EXTENT]->(Date)
(Product)-[:SPATIAL_EXTENT]->(SpatialExtent)
(Product)-[:HAS_SENSOR_TYPE]->(SensorType)
(Product)-[:HAS_ISO_STANDARD]->(ISOStandard)
(Product)-[:HAS_ORBIT_TYPE]->(OrbitType)
(Product)-[:HAS_PLATFORM]->(Platform)
(Product)-[:HAS_INSTRUMENT]->(Instrument)
(Product)-[:HAS_COMPOSITE_TYPE]->(CompositeType)


"""

# %%
from langchain_experimental.graph_transformers import LLMGraphTransformer
from langchain_openai import ChatOpenAI

llm = ChatOpenAI(temperature=0, model_name ="gpt-4o-mini")

llm_transformer = LLMGraphTransformer(llm=llm) 

from langchain_core.documents import Document

documents = [Document(page_content=metadata_text)]
graph_documents = llm_transformer.convert_to_graph_documents(documents)
print(f"Nodes:{graph_documents[0].nodes}")
print(f"Relationships:{graph_documents[0].relationships}")
# Out:
# Nodes:[Node(id='Sentinel-2 L2A Maja', type='Product', properties={}), Node(id='German Aerospace Center (Dlr)', type='Organization', properties={}), Node(id='Pablo Angelo', type='Person', properties={}), Node(id='Epsg:4326 (Wgs 84)', type='Referencesystem', properties={}), Node(id='Satellite', type='Keyword', properties={}), Node(id='Earth Observation', type='Keyword', properties={}), Node(id='Multispectral', type='Keyword', properties={}), Node(id='Sentinel-2', type='Keyword', properties={}), Node(id='Msi', type='Keyword', properties={}), Node(id='Level 2A', type='Keyword', properties={}), Node(id='Maja', type='Keyword', properties={}), Node(id='Atmospheric Correction', type='Keyword', properties={}), Node(id='Cloud Detection', type='Keyword', properties={}), Node(id='Https://Tinyurl.Com/Mr2X5Hm5', type='Downloadlink', properties={}), Node(id='Optical', type='Sensortype', properties={}), Node(id='2024-07-12T09:25:33', type='Date', properties={}), Node(id='Iso 19115 : 2003/Cor.1:2006'
# ...

# %%
graph.add_graph_documents(graph_documents)

# %%
# create the index

import os
from langchain.vectorstores.neo4j_vector import Neo4jVector
from langchain_openai import OpenAIEmbeddings

vector_index = Neo4jVector.from_existing_graph(
    OpenAIEmbeddings(),
    url=NEO4J_URI,
    username=NEO4J_USERNAME,
    password=NEO4J_PASSWORD,
    index_name='index_for_Product',
    node_label="Product",
    text_node_properties= ['name', 'date', 'sensorType', 'organization', 'orbitType', 'spatialExtent', 'instrument', 'isoStandard', 'visualizationUrl', 'referenceSystem', 'platform', 'compositeType'], 

    embedding_node_property='embedding',
)

# %%
# see the index just created
vector_index.query(
    """SHOW INDEXES
       YIELD name, type, labelsOrTypes, properties, options
       WHERE type = 'VECTOR'
    """
)
# Out:
# [{'name': 'index_for_Product',
#   'type': 'VECTOR',
#   'labelsOrTypes': ['Product'],
#   'properties': ['embedding'],
#   'options': {'indexProvider': 'vector-2.0',
#    'indexConfig': {'vector.hnsw.m': 16,
#     'vector.hnsw.ef_construction': 100,
#     'vector.dimensions': 1536,
#     'vector.similarity_function': 'COSINE',
#     'vector.quantization.enabled': True}}}]

# %%
question1 = "What is the sensor type of Sentinel-2 L2A Maja Products"
question2 =  "What is the spatial extent of Sentinel-2 L2A Maja Products?"
question3 =  "What is the Temporal extent of Sentinel-2 L2A Maja Products?"
question4 =  "Give me the download links for Sentinel-2 L2A Maja Products?"
question5 =  "What is the DOI for Sentinel-2 L2A Maja Products?" 
question6 =  "What is the reference system used for Sentinel-2 L2A Maja Products?"
question7 =  "What is the ISO standards for Sentinel-2 L2A Maja Products?"
question8 =  "list the tiles covered by Sentinel-2 L2A Maja Products?"
question9 =  "what is the orbit type of Sentinel-2 L2A Maja Products?"
question10 =  "provide the geojson of Sentinel-2 L2A Maja Products?"
question11 =  "provide the json of Sentinel-2 L2A Maja Products?" 
question12 =  "what is the visualisation link of EnMAP L2A HSI Productsook Products?"
question13 =  "provide all the keywords of Sentinel-2 L2A MAjA Products?"
question14 =  "what is the saptial extent of S5P Tropomi L3 P1D COT?"

# %%
response = vector_index.similarity_search(question1)
response
# Out:
# [Document(metadata={'temporalExtent': '2024-07-12T09:25:33', 'downloadLink': 'https://download.geoservice.dlr.de/S2_L2A_MAJA/', 'geojsonUrl': 'https://geoservice.dlr.de/eoc/oseo/search?identifier=S2_L2A_MAJA&httpAccept=application/geo%2Bjson'}, page_content='\nname: Sentinel-2 L2A Maja\ndate: \nsensorType: Optical\norganization: \norbitType: LEO\nspatialExtent: 5.7635, 46.7937, 15.1528, 55.9456\ninstrument: \nisoStandard: ISO 19115 : 2003/Cor.1:2006\nvisualizationUrl: https://geoservice.dlr.de/web/maps/sentinel2:l2a:maja\nreferenceSystem: EPSG:4326 (WGS 84)\nplatform: \ncompositeType: '),
# ...

# %%
# using documents as context
from langchain_openai import ChatOpenAI
from langchain.prompts import ChatPromptTemplate

template = """Answer the question based only on the following context:
{context}

Question: {question}
"""

prompt = ChatPromptTemplate.from_template(template)
prompt
# Out:
# ChatPromptTemplate(input_variables=['context', 'question'], input_types={}, partial_variables={}, messages=[HumanMessagePromptTemplate(prompt=PromptTemplate(input_variables=['context', 'question'], input_types={}, partial_variables={}, template='Answer the question based only on the following context:\n{context}\n\nQuestion: {question}\n'), additional_kwargs={})])

# %%
llm = ChatOpenAI(model_name="gpt-3.5-turbo", temperature=0)

# %%
chain = prompt | llm

# %%
docs = response

chain.invoke({"context": docs, "question": question14}).content
# Out:
# 'The provided context does not contain information about the spatial extent of S5P Tropomi L3 P1D COT.'

# %%
# Using a retriever as context
from langchain_openai import ChatOpenAI
from langchain.prompts import ChatPromptTemplate
from langchain_core.output_parsers import StrOutputParser
from langchain_core.runnables import RunnablePassthrough

template = """Answer the question based only on the following context:
{context}

Question: {question}
"""

prompt = ChatPromptTemplate.from_template(template)
llm = ChatOpenAI(model_name="gpt-3.5-turbo", temperature=0)

retriever = vector_index.as_retriever() # search_kwargs={"k": 1}

graph_chain = ({"context": retriever, "question": RunnablePassthrough()}
                | prompt
                | llm
                | StrOutputParser()
                )
graph_chain.invoke(question3)
# Out:
# "The Temporal extent of Sentinel-2 L2A Maja Products is '2024-07-12T09:25:33'."

# %%
# Using a custom retriever as a context and post-processing of the answer
# https://python.langchain.com/docs/how_to/custom_retriever/
from typing import List
from langchain_core.callbacks import CallbackManagerForRetrieverRun
from langchain_core.documents import Document
from langchain_core.retrievers import BaseRetriever

class CustomRetriever(BaseRetriever):
    """ Custom retriever to return the scores of the documents as well.
        Then the scores are passed into an custom ranking function to include the spatial similarity
        between the query and the document.
    """

    vector_index: Neo4jVector

    def _get_relevant_documents(
        self, query: str, *, run_manager: CallbackManagerForRetrieverRun
    ) -> List[Document]:
        """Sync implementations for retriever."""

        docs, scores = zip(*self.vector_index.similarity_search_with_score(query))
        for doc, score in zip(docs, scores):
             print("***", doc)
             #new_score = updated_score(score, query, doc)
             doc.page_content = doc.page_content
             doc.metadata["score"] = score
        return docs

def update_scores(docs):

    for doc in docs:
       new_score = doc.metadata["score"] * 10
       doc.page_content = doc.page_content+ "\nScore: " + str(new_score)
       doc.metadata["score"] = new_score
    return docs

# %%
from langchain_openai import ChatOpenAI
from langchain.prompts import ChatPromptTemplate
from langchain_core.output_parsers import StrOutputParser
from langchain_core.runnables import RunnablePassthrough

template = """Answer the question based only on the following context:
{context}

Question: {question}
"""

prompt = ChatPromptTemplate.from_template(template)
llm = ChatOpenAI(model_name="gpt-3.5-turbo", temperature=0)

retriever_r = CustomRetriever(vector_index=vector_index)

graph_chain = ({"context": retriever_r | update_scores, "question": RunnablePassthrough()}
                | prompt
                | llm
                | StrOutputParser()
                )

graph_chain.invoke(question6)
# Out:
# *** page_content='
# name: Sentinel-2 L2A Maja
# date:
# sensorType: Optical
# organization:
# orbitType: LEO
# spatialExtent: 5.7635, 46.7937, 15.1528, 55.9456
# instrument:
# isoStandard: ISO 19115 : 2003/Cor.1:2006
# visualizationUrl: https://geoservice.dlr.de/web/maps/sentinel2:l2a:maja
# referenceSystem: EPSG:4326 (WGS 84)
# platform:
# compositeType: ' metadata={'temporalExtent': '2024-07-12T09:25:33', 'downloadLink': 'https://download.geoservice.dlr.de/S2_L2A_MAJA/', 'geojsonUrl': 'https://geoservice.dlr.de/eoc/oseo/search?identifier=S2_L2A_MAJA&httpAccept=application/geo%2Bjson'}
# *** page_content='
# name: Sentinel-2 L2A Maja
# date:
# sensorType: Optical
# organization:
# orbitType: LEO
# spatialExtent: 5.7635, 46.7937, 15.1528, 55.9456
# instrument:
# isoStandard: ISO 19115 : 2003/Cor.1:2006
# visualizationUrl: https://geoservice.dlr.de/web/maps/sentinel2:l2a:maja
# referenceSystem: EPSG:4326 (WGS 84)
# platform:
# ...
